# %%
import json
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import torch
import statistics

# %run ../Codes/Data_handling.ipynb
# Out:
# 316
# 319
# 50

# %%
def mean_list(list_of_lists):
    mean_list = []
    sd_list = []
    values_list = []

    for j in range(len(list_of_lists[0])):
        current_values =[]
        for i in list_of_lists:
            current_values.append(i[j])
        values_list.append(current_values)
    print(values_list)
    for i in values_list:
        mean_list.append(sum(i) / len(i))
        sd_list.append(statistics.pstdev(i))

    mean_plus_sd_list = np.add(mean_list,sd_list)
    mean_minus_sd_list = np.subtract(mean_list,sd_list)

    return mean_list, mean_plus_sd_list, mean_minus_sd_list

# %%
def double_sd_list(list_of_lists):
    mean_list = []
    sd_list = []
    values_list = []

    for j in range(len(list_of_lists[0])):
        current_values =[]
        for i in list_of_lists:
            current_values.append(i[j])
        values_list.append(current_values)
    print(values_list)
    for i in values_list:
        mean_list.append(sum(i) / len(i))
        sd_list.append(statistics.pstdev(i))

    mean_plus_sd_list = np.add(mean_list,sd_list)
    mean_plus_sd_list = np.add(mean_plus_sd_list,sd_list)
    mean_minus_sd_list = np.subtract(mean_list,sd_list)
    mean_minus_sd_list = np.subtract(mean_minus_sd_list,sd_list)

    return mean_plus_sd_list, mean_minus_sd_list

# %%
data = torch.load('../Data/data.pth')

# %%
with open('../gnn_outputs/edges_to_hide_30_smart.json', 'r') as file:
    edges_to_hide = json.load(file)
data_train = torch.load('../Data/data_train.pth')
data_test = torch.load('../Data/data_test.pth')

prepared_training_data, prepared_training_data_hiden, prepared_test_data, prepared_test_data_hiden, summa = data_preparation(data_train, data_test, edges_to_hide, True)

# %%
prepared_training_data[1].edge_attr[edges_to_hide]
benchmark = 0
count = 0
for i in prepared_test_data:
    for j in i.edge_attr[edges_to_hide]:
        benchmark += j*j
        count += 1 

for i in prepared_training_data:
    for j in i.edge_attr[edges_to_hide]:
        benchmark += j*j
        count += 1 

benchmark = float(benchmark/count)
print(benchmark)
# Out:
# 0.006680180784314871

# %%
with open('losses_30_smart.json', 'r') as file:
    losses_30_smart = json.load(file)

with open('losses_30_random.json', 'r') as file:
    losses_30_random = json.load(file)

# %%
with open('losses_20_smart.json', 'r') as file:
    losses_20_smart = json.load(file)

with open('losses_20_random.json', 'r') as file:
    losses_20_random = json.load(file)

# %%
with open('losses_10_smart.json', 'r') as file:
    losses_10_smart = json.load(file)

with open('losses_10_random.json', 'r') as file:
    losses_10_random = json.load(file)

# %%
with open('losses_30_smart_5k.json', 'r') as file:
    losses_30_smart_5k_v1 = json.load(file)

with open('losses_20_smart_5k.json', 'r') as file:
    losses_20_smart_5k_v1 = json.load(file)

with open('losses_10_smart_5k.json', 'r') as file:
    losses_10_smart_5k_v1 = json.load(file)

# %%
with open('losses_30_random_5k.json', 'r') as file:
    losses_30_random_5k_v1 = json.load(file)

with open('losses_20_random_5k.json', 'r') as file:
    losses_20_random_5k_v1 = json.load(file)

with open('losses_10_random_5k.json', 'r') as file:
    losses_10_random_5k_v1 = json.load(file)

# %%
with open('losses_30_random_5k_v2.json', 'r') as file:
    losses_30_random_5k_v2 = json.load(file)

with open('losses_30_random_5k_v3.json', 'r') as file:
    losses_30_random_5k_v3 = json.load(file)

with open('losses_30_random_5k_v4.json', 'r') as file:
    losses_30_random_5k_v4 = json.load(file)

with open('losses_30_random_5k.json', 'r') as file:
    losses_30_random_5k_v5 = json.load(file)

with open('losses_0.7_random_5_v6.json', 'r') as file:
    losses_30_random_5k_v6 = json.load(file)

with open('losses_0.7_random_5_v7.json', 'r') as file:
    losses_30_random_5k_v7 = json.load(file)

with open('losses_0.7_random_5_v8.json', 'r') as file:
    losses_30_random_5k_v8 = json.load(file)

with open('losses_0.7_random_5_v9.json', 'r') as file:
    losses_30_random_5k_v9 = json.load(file)

with open('losses_0.7_random_5_v10.json', 'r') as file:
    losses_30_random_5k_v10 = json.load(file)



r_losslist_30 = [losses_30_random_5k_v1[2], losses_30_random_5k_v2[2], losses_30_random_5k_v3[2], losses_30_random_5k_v4[2], losses_30_random_5k_v5[2],
                 losses_30_random_5k_v6[2], losses_30_random_5k_v7[2], losses_30_random_5k_v8[2], losses_30_random_5k_v9[2], losses_30_random_5k_v10[2]]

r_30_mean, r_30_high, r_30_low = mean_list(r_losslist_30)
# Out:
# [[0.004792655818164349, 0.005114599596709013, 0.006857110653072596, 0.019208943471312523, 0.004792655818164349, 0.03771820664405823, 0.03526093065738678, 0.030069636180996895, 0.007080955896526575, 0.00509996060281992], [0.004504283424466848, 0.004701673053205013, 0.0044231475330889225, 0.005756328348070383, 0.004504283424466848, 0.00514586828649044, 0.005490969400852919, 0.004691627807915211, 0.004592321813106537, 0.004823161289095879], [0.004515801090747118, 0.004690159112215042, 0.00443389592692256, 0.005765548907220364, 0.004515801090747118, 0.004611616488546133, 0.005195269826799631, 0.004565677605569363, 0.0045036436058580875, 0.004850844852626324], [0.004484723322093487, 0.004707130137830973, 0.004380757454782724, 0.005433118902146816, 0.004484723322093487, 0.004491574130952358, 0.005067766178399324, 0.004545227624475956, 0.004664797801524401, 0.00472441129386425], [0.004473784472793341, 0.004686111118644476, 0.00437984149903059, 0.005252521485090256, 0.004473784472793341, 0.0
# ...

# %%
with open('losses_0.8_random_5_v2.json', 'r') as file:
    losses_20_random_5k_v2 = json.load(file)

with open('losses_0.8_random_5_v3.json', 'r') as file:
    losses_20_random_5k_v3 = json.load(file)

with open('losses_0.8_random_5_v4.json', 'r') as file:
    losses_20_random_5k_v4 = json.load(file)

with open('losses_0.8_random_5_v5.json', 'r') as file:
    losses_20_random_5k_v5 = json.load(file)

with open('losses_0.8_random_5_v6.json', 'r') as file:
    losses_20_random_5k_v6 = json.load(file)

with open('losses_0.8_random_5_v7.json', 'r') as file:
    losses_20_random_5k_v7 = json.load(file)

with open('losses_0.8_random_5_v8.json', 'r') as file:
    losses_20_random_5k_v8 = json.load(file)

with open('losses_0.8_random_5_v9.json', 'r') as file:
    losses_20_random_5k_v9 = json.load(file)

with open('losses_0.8_random_5_v10.json', 'r') as file:
    losses_20_random_5k_v10 = json.load(file)
r_losslist_20 = [losses_20_random_5k_v1[2], losses_20_random_5k_v2[2], losses_20_random_5k_v3[2], losses_20_random_5k_v4[2], losses_20_random_5k_v5[2],
                 losses_20_random_5k_v6[2], losses_20_random_5k_v7[2], losses_20_random_5k_v8[2], losses_20_random_5k_v9[2], losses_20_random_5k_v10[2]]

r_20_mean, r_20_high, r_20_low = mean_list(r_losslist_20)
# Out:
# [[0.010207840241491795, 0.019056079909205437, 0.004827780183404684, 0.0048119318671524525, 0.008684184402227402, 0.04873369634151459, 0.016897734254598618, 0.02698671817779541, 0.046749018132686615, 0.0049858661368489265], [0.004738765303045511, 0.0056357719004154205, 0.004824179224669933, 0.0047092558816075325, 0.00454868795350194, 0.004822450689971447, 0.0051232087425887585, 0.005619757808744907, 0.005642944481223822, 0.004765157122164965], [0.004746152088046074, 0.004838495049625635, 0.004779534880071878, 0.004698595497757196, 0.004466941114515066, 0.004539891611784697, 0.004805517382919788, 0.005167828407138586, 0.004601019434630871, 0.004754246678203344], [0.004732784349471331, 0.005185261834412813, 0.004832790233194828, 0.004739917349070311, 0.004428524989634752, 0.004471698775887489, 0.004786534234881401, 0.004933983087539673, 0.004530309233814478, 0.004798159468919039], [0.004690986126661301, 0.00469423970207572, 0.004765049554407597, 0.004750526510179043, 0.00441363127902150
# ...

# %%
with open('losses_0.9_random_5_v2.json', 'r') as file:
    losses_10_random_5k_v2 = json.load(file)

with open('losses_0.9_random_5_v3.json', 'r') as file:
    losses_10_random_5k_v3 = json.load(file)

with open('losses_0.9_random_5_v4.json', 'r') as file:
    losses_10_random_5k_v4 = json.load(file)

with open('losses_0.9_random_5_v5.json', 'r') as file:
    losses_10_random_5k_v5 = json.load(file)

with open('losses_0.9_random_5_v6.json', 'r') as file:
    losses_10_random_5k_v6 = json.load(file)

with open('losses_0.9_random_5_v7.json', 'r') as file:
    losses_10_random_5k_v7 = json.load(file)

with open('losses_0.9_random_5_v8.json', 'r') as file:
    losses_10_random_5k_v8 = json.load(file)

with open('losses_0.9_random_5_v9.json', 'r') as file:
    losses_10_random_5k_v9 = json.load(file)

with open('losses_0.9_random_5_v10.json', 'r') as file:
    losses_10_random_5k_v10 = json.load(file)
r_losslist_10 = [losses_10_random_5k_v1[2], losses_10_random_5k_v2[2], losses_10_random_5k_v3[2], losses_10_random_5k_v4[2], losses_10_random_5k_v5[2],
                 losses_10_random_5k_v6[2], losses_10_random_5k_v7[2], losses_10_random_5k_v8[2], losses_10_random_5k_v9[2], losses_10_random_5k_v10[2]]

r_10_mean, r_10_high, r_10_low = mean_list(r_losslist_10)
r_10_double_high, r_10_double_low = double_sd_list(r_losslist_10)
# Out:
# [[0.004917573649436235, 0.007360588759183884, 0.013506920076906681, 0.038517873734235764, 0.00450379541143775, 0.008104360662400723, 0.02506416290998459, 0.004762709606438875, 0.00464067654684186, 0.004887669812887907], [0.00478983111679554, 0.005247157067060471, 0.004921364597976208, 0.005294258706271648, 0.00448123412206769, 0.0049086459912359715, 0.004955816548317671, 0.0046139187179505825, 0.0046676467172801495, 0.004858596716076136], [0.004758835304528475, 0.005142839625477791, 0.004894462414085865, 0.005022475961595774, 0.004469275940209627, 0.004860965069383383, 0.005027707200497389, 0.004577150568366051, 0.004642849788069725, 0.0049112276174128056], [0.004793060943484306, 0.004759627394378185, 0.00486820749938488, 0.004926914814859629, 0.004508850630372763, 0.004756525158882141, 0.004975135438144207, 0.0046285055577754974, 0.0046402220614254475, 0.004836442414671183], [0.004737339913845062, 0.004820999689400196, 0.004872452933341265, 0.004835339728742838, 0.004482690710574388
# ...

# %%
with open('losses_0.7_smart_5_v2.json', 'r') as file:
    losses_30_smart_5k_v2 = json.load(file)

with open('losses_0.7_smart_5_v3.json', 'r') as file:
    losses_30_smart_5k_v3 = json.load(file)

with open('losses_0.7_smart_5_v4.json', 'r') as file:
    losses_30_smart_5k_v4 = json.load(file)

with open('losses_0.7_smart_5_v5.json', 'r') as file:
    losses_30_smart_5k_v5 = json.load(file)

with open('losses_0.7_smart_5_v6.json', 'r') as file:
    losses_30_smart_5k_v6 = json.load(file)

with open('losses_0.7_smart_5_v7.json', 'r') as file:
    losses_30_smart_5k_v7 = json.load(file)

with open('losses_0.7_smart_5_v8.json', 'r') as file:
    losses_30_smart_5k_v8 = json.load(file)

with open('losses_0.7_smart_5_v9.json', 'r') as file:
    losses_30_smart_5k_v9 = json.load(file)

with open('losses_0.7_smart_5_v10.json', 'r') as file:
    losses_30_smart_5k_v10 = json.load(file)



s_losslist_30 = [losses_30_smart_5k_v1[2], losses_30_smart_5k_v2[2], losses_30_smart_5k_v3[2], losses_30_smart_5k_v4[2], losses_30_smart_5k_v5[2],
                 losses_30_smart_5k_v6[2], losses_30_smart_5k_v7[2], losses_30_smart_5k_v8[2], losses_30_smart_5k_v9[2], losses_30_smart_5k_v10[2]]

s_30_mean, s_30_high, s_30_low = mean_list(s_losslist_30)
# Out:
# [[0.025811342522501945, 0.00457636546343565, 0.005031383130699396, 0.006632511038333178, 0.006454082205891609, 0.015353573486208916, 0.016368679702281952, 0.025650540366768837, 0.012667766772210598, 0.004999397788196802], [0.004382132086902857, 0.004558453802019358, 0.004135884344577789, 0.0042202407494187355, 0.004226820543408394, 0.0048414673656225204, 0.004503986798226833, 0.004328353330492973, 0.004174775443971157, 0.004070184659212828], [0.004289332311600447, 0.0045413547195494175, 0.0041588833555579185, 0.004224451258778572, 0.004258232191205025, 0.004538610577583313, 0.0044697304256260395, 0.004251871723681688, 0.004142171703279018, 0.0040207067504525185], [0.004311234224587679, 0.004558132495731115, 0.004132970701903105, 0.0042313868179917336, 0.004370656795799732, 0.004556340631097555, 0.0044556488282978535, 0.0042902203276753426, 0.0041222176514565945, 0.004151052329689264], [0.004223586991429329, 0.004542297217994928, 0.004128394648432732, 0.004191807005554438, 0.004257203
# ...

# %%
with open('losses_0.8_smart_5_v2.json', 'r') as file:
    losses_20_smart_5k_v2 = json.load(file)

with open('losses_0.8_smart_5_v3.json', 'r') as file:
    losses_20_smart_5k_v3 = json.load(file)

with open('losses_0.8_smart_5_v4.json', 'r') as file:
    losses_20_smart_5k_v4 = json.load(file)

with open('losses_0.8_smart_5_v5.json', 'r') as file:
    losses_20_smart_5k_v5 = json.load(file)

with open('losses_0.8_smart_5_v6.json', 'r') as file:
    losses_20_smart_5k_v6 = json.load(file)

with open('losses_0.8_smart_5_v7.json', 'r') as file:
    losses_20_smart_5k_v7 = json.load(file)

with open('losses_0.8_smart_5_v8.json', 'r') as file:
    losses_20_smart_5k_v8 = json.load(file)

with open('losses_0.8_smart_5_v9.json', 'r') as file:
    losses_20_smart_5k_v9 = json.load(file)

with open('losses_0.8_smart_5_v10.json', 'r') as file:
    losses_20_smart_5k_v10 = json.load(file)
s_losslist_20 = [losses_20_smart_5k_v1[2], losses_20_smart_5k_v2[2], losses_20_smart_5k_v3[2], losses_20_smart_5k_v4[2], losses_20_smart_5k_v5[2],
                 losses_20_smart_5k_v6[2], losses_20_smart_5k_v7[2], losses_20_smart_5k_v8[2], losses_20_smart_5k_v9[2], losses_20_smart_5k_v10[2]]

s_20_mean, s_20_high, s_20_low = mean_list(s_losslist_20)
# Out:
# [[0.004266479983925819, 0.00443044351413846, 0.008308601565659046, 0.009946851991117, 0.005399907939136028, 0.013160312548279762, 0.01759347878396511, 0.02436010353267193, 0.004217616282403469, 0.013483753427863121], [0.003947055898606777, 0.004058682359755039, 0.004184680059552193, 0.0038771992549300194, 0.004071724601089954, 0.004340607672929764, 0.0046570636332035065, 0.004367854446172714, 0.003976683598011732, 0.003920513670891523], [0.003940981812775135, 0.0041168672032654285, 0.004068267066031694, 0.0038523972034454346, 0.004031366668641567, 0.004136496689170599, 0.004133859183639288, 0.004233851097524166, 0.003977591637521982, 0.003854164620861411], [0.003937651868909597, 0.003995820414274931, 0.0040147691033780575, 0.003864231752231717, 0.0039663417264819145, 0.0040686000138521194, 0.003985815681517124, 0.0040763188153505325, 0.003975674044340849, 0.003853545757010579], [0.003932683728635311, 0.003992888610810041, 0.004016765858978033, 0.0038444409146904945, 0.004012301564216
# ...

# %%
with open('losses_0.9_smart_5_v2.json', 'r') as file:
    losses_10_smart_5k_v2 = json.load(file)

with open('losses_0.9_smart_5_v3.json', 'r') as file:
    losses_10_smart_5k_v3 = json.load(file)

with open('losses_0.9_smart_5_v4.json', 'r') as file:
    losses_10_smart_5k_v4 = json.load(file)

with open('losses_0.9_smart_5_v5.json', 'r') as file:
    losses_10_smart_5k_v5 = json.load(file)

with open('losses_0.9_smart_5_v6.json', 'r') as file:
    losses_10_smart_5k_v6 = json.load(file)

with open('losses_0.9_smart_5_v7.json', 'r') as file:
    losses_10_smart_5k_v7 = json.load(file)

with open('losses_0.9_smart_5_v8.json', 'r') as file:
    losses_10_smart_5k_v8 = json.load(file)

with open('losses_0.9_smart_5_v9.json', 'r') as file:
    losses_10_smart_5k_v9 = json.load(file)

with open('losses_0.9_smart_5_v10.json', 'r') as file:
    losses_10_smart_5k_v10 = json.load(file)

s_losslist_10 = [losses_10_smart_5k_v1[2], losses_10_smart_5k_v2[2], losses_10_smart_5k_v3[2], losses_10_smart_5k_v4[2], losses_10_smart_5k_v5[2],
                 losses_10_smart_5k_v6[2], losses_10_smart_5k_v7[2], losses_10_smart_5k_v8[2], losses_10_smart_5k_v9[2], losses_10_smart_5k_v10[2]]

s_10_mean, s_10_high, s_10_low = mean_list(s_losslist_10)
#r_10_double_high, r_10_double_low = double_sd_list(r_losslist_10)
# Out:
# [[0.02083866484463215, 0.005770513787865639, 0.004285760223865509, 0.004362957086414099, 0.007716616149991751, 0.00904635339975357, 0.004999377764761448, 0.004101461730897427, 0.007108595222234726, 0.009312092326581478], [0.004363572224974632, 0.004008290357887745, 0.0041213189251720905, 0.004095668438822031, 0.004161907825618982, 0.004134045913815498, 0.004222769755870104, 0.004114299081265926, 0.0042714569717645645, 0.004016936291009188], [0.004180082585662603, 0.004118466284126043, 0.004131261724978685, 0.0040990677662193775, 0.004153106827288866, 0.00415744399651885, 0.004235442262142897, 0.004110450856387615, 0.004258795641362667, 0.0039923288859426975], [0.004204604774713516, 0.003979095723479986, 0.004255109000951052, 0.0041366200894117355, 0.004146548919379711, 0.004071763250976801, 0.00419659074395895, 0.0040740701369941235, 0.004191488493233919, 0.003954947926104069], [0.004260563757270575, 0.003967459313571453, 0.004176778718829155, 0.004080395679920912, 0.0041499636135995
# ...

# %%
matplotlib.rcParams.update({'font.size': 14})

# %%
plt.plot(s_30_mean[1:], label = "Zone-based-30", color = 'r')
plt.plot(s_20_mean[1:], label = "Zone-based-20", color = 'g')
plt.plot(s_10_mean[1:], label = "Zone-based-10", color = 'b')
plt.legend(loc="upper right")
plt.xlabel('20 Epochs')
plt.ylabel('Loss')
plt.show()

# %%
#plt.yscale("log")
plt.plot(losses_10_smart[1][8:], 'ro', losses_20_smart[2][8:], 'go', losses_30_smart[1][8:], 'bo', losses_30_random[2][8:], 'yo',losses_10_random[2][8:], 'co',losses_20_random[2][8:], 'mo')

# %%
plt.plot(s_30_mean[1:], label = "Zone-based-30", color = 'r')
plt.plot(r_30_mean[1:], label = "Random-30", color = 'b')
plt.plot(s_20_mean[1:],  label = "Zone-based-20", color = 'y')
plt.plot(r_20_mean[1:], label = "Random-20", color = 'c')
plt.plot(s_10_mean[1:], label = "Zone-based-10", color = 'm')
plt.plot(r_10_mean[1:], label = "Random-10", color = 'g')
#plt.fill_between(range(len(r_30_high[1:])),r_30_high[1:],r_30_low[1:], alpha = 0.1, color = 'b')
#plt.fill_between(range(len(r_20_high[1:])),r_20_high[1:],r_20_low[1:], alpha = 0.1, color = 'c')
#plt.fill_between(range(len(r_10_high[1:])),r_10_high[1:],r_10_low[1:], alpha = 0.1, color = 'g')
#plt.fill_between(range(len(r_10_high[1:])),r_10_double_high[1:],r_10_double_low[1:], alpha = 0.1, color = 'g')
#plt.fill_between(range(len(s_30_high[1:])),s_30_high[1:],s_30_low[1:], alpha = 0.1, color = 'r')
#plt.fill_between(range(len(s_20_high[1:])),s_20_high[1:],s_20_low[1:], alpha = 0.1, color = 'y')
#plt.fill_between(range(len(s_10_high[1:])),s_10_high[1:],s_10_low[1:], alpha = 0.1, color = 'm')
plt.legend(bbox_to_anchor=(1.04, 1.0), loc="upper left")
plt.xlabel('20Epochs')
plt.ylabel('Loss')
plt.show()

# %%
losses_30_smart_MA = []
averrange = 20
for i in range(averrange):
    losses_30_smart_MA.append(np.nan)
for i in range(len(losses_30_smart[0])-averrange):
    suma = 0
    for j in range(averrange):
        suma += losses_30_smart[0][i+j]
    aver = suma / averrange
    losses_30_smart_MA.append(aver)

# %%
plt.plot(losses_30_smart[0], 'ro', label = "strategy30")
plt.legend(loc="upper right")
plt.xlabel('NOI')
plt.ylabel('MSE')
plt.show()

# %%
losses_30_smart_MA = []
averrange = 20
for i in range(averrange):
    losses_30_smart_MA.append(np.nan)
for i in range(len(losses_30_smart_5k_v1[0])-averrange):
    suma = 0
    for j in range(averrange):
        suma += losses_30_smart_5k_v1[0][i+j]
    aver = suma / averrange
    losses_30_smart_MA.append(aver)

plt.axhline(y = benchmark, color = 'g', linestyle = '-')
plt.plot(losses_30_smart_5k_v1[0][10:], 'r', label = "Zone-based-30")
plt.plot(losses_30_smart_MA[10:], 'b', label = "Zone-based-30-MA")
plt.legend(loc="upper right")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# %%
plt.plot(losses_20_smart[2], 'ro', label = "strategy 30 test")
plt.plot(losses_20_smart[1], 'bo', label = "strategy 30 train")
plt.legend(loc="upper right")
plt.xlabel('NOI')
plt.ylabel('MSE')
plt.show()

# %%
plt.plot(losses_30_smart[1], 'ro', losses_30_smart[2], 'go')
