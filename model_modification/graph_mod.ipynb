# %%
import json
import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# Base models [32, 128, 64, 32, 32, 32, 32, 32]

# %%
with open('losses_30_smart.json', 'r') as file:
    losses_30_smart = json.load(file)

with open('losses_20_smart.json', 'r') as file:
    losses_20_smart = json.load(file)

# %% [markdown]
# Models with higher number of dimensions

# %%
with open('losses_20_smart_mod1.json', 'r') as file:
    losses_20_smart_mod1 = json.load(file)

with open('losses_20_smart_mod2.json', 'r') as file:
    losses_20_smart_mod2 = json.load(file)

with open('losses_20_smart_mod3.json', 'r') as file:
    losses_20_smart_mod3 = json.load(file)

with open('losses_20_smart_mod4.json', 'r') as file:
    losses_20_smart_mod4 = json.load(file)

# %% [markdown]
# Models with lower number of dimensions

# %%
with open('losses_20_smart_mod5.json', 'r') as file:
    losses_20_smart_mod5 = json.load(file)

with open('losses_20_smart_mod6.json', 'r') as file:
    losses_20_smart_mod6 = json.load(file)

with open('losses_20_smart_mod7.json', 'r') as file:
    losses_20_smart_mod7 = json.load(file)

with open('losses_20_smart_mod8.json', 'r') as file:
    losses_20_smart_mod8 = json.load(file)
    
with open('losses_20_smart_mod9.json', 'r') as file:
    losses_20_smart_mod9 = json.load(file)

# %%
plt.plot(losses_30_smart[2][4:], 'ro', losses_20_smart[2][4:], 'go',  losses_20_smart_mod1[2][4:], 'bo',  losses_20_smart_mod2[2][4:], 'yo',  losses_20_smart_mod3[2][4:], 'co', losses_20_smart_mod3[2][4:], 'mo')

# %%
plt.yscale("log")
plt.plot(losses_30_smart[2][4:], 'ro',losses_20_smart[2][4:], 'go',  losses_20_smart_mod1[2][4:], 'bo',  losses_20_smart_mod2[2][4:], 'yo',  losses_20_smart_mod3[2][4:], 'co', losses_20_smart_mod3[2][4:], 'mo')

# %%
plt.yscale("log")
plt.plot(losses_20_smart[2][4:20], 'go',  losses_20_smart_mod1[2][4:20], 'bo',  losses_20_smart_mod2[2][4:20], 'yo',  losses_20_smart_mod3[2][4:20], 'co', losses_20_smart_mod3[2][4:20], 'mo')

# %%
plt.yscale("log")
plt.plot(losses_20_smart_mod9[2][4:], 'ro',losses_20_smart[2][4:], 'go',  losses_20_smart_mod5[2][4:], 'bo',  losses_20_smart_mod6[2][4:], 'yo',  losses_20_smart_mod7[2][4:], 'co', losses_20_smart_mod8[2][4:], 'mo')
